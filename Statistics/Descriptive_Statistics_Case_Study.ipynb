# %% [markdown]
# ## A Case Study on Descriptive Statistics for Data Science

# %% [markdown]
# ## Introduction
#
# Descriptive statistics refers to the study of numerical and graphical methods to describe and present the data. By summarising the provided sample set or population of data, it characterises the data and aids in our understanding of its characteristics. In short, the type of statistics used to summarise and characterise the dataset is called descriptive statistics. It is employed to explain the properties of data.

# %% [markdown]
# ## Describing the dataset
#
# This dataset offers nutrition information for around 8.8k different types of food. The titles of the features are self-explanatory, therefore I won't go into detail about them. Access the dataset : [nutrition data](https://colab.research.google.com/drive/1szFExQLNstWDneCvsOQjd-xheAL7ZmmN?usp=sharing)
#
#
# <br>
#
# **name** : Name of the foods
#
# **calories** : Total ammount of calories present in the food
#
# **total_fat** : Total fat ammount present in the food
#
# **saturated_fat** : Total ammount of saturated_fat present
#
# **cholesterol** : Total ammount of cholesterol present
#
# **sodium** : Total ammount of sodium present
#
# **choline** : Total ammount of choline present
#
# **folate** : Total ammount of folate present
#
# **folic_acid** : Total ammount of folic_acid present
#
# **niacin** : Total ammount of niacin present
#
# **pantothenic_acid** : Total ammount of pantothenic_acid present
#
# **riboflavin** : Total ammount of riboflavin present
#
# **thiamin** : Total ammount of thiamin present
#
# **vitamin_a** : Total ammount of vitamin_a present
#
# **vitamin_a_rae** : Total ammount of vitamin_a_rae present
#
# **carotene_alpha** : Total ammount of carotene_alpha present
#
# **carotene_beta** : Total ammount of carotene_beta present
#
# **cryptoxanthin_beta** : Total ammount of cryptoxanthin_beta present
#
# **lutein_zeaxanthin** : Total ammount of lutein_zeaxanthin present
#
# **lucopene** : Total ammount of lucopene present
#
# **vitamin_b12** : Total ammount of vitamin_b12 present
#
# **vitamin_b6** : Total ammount of vitamin_b6 present
#
# **vitamin_c** : Total ammount of vitamin_c present
#
# **vitamin_d** : Total ammount of vitamin_d present
#
# **vitamin_e** : Total ammount of vitamin_e present
#
# **tocopherol_alpha** : Total ammount of tocopherol_alpha present
#
# **vitamin_k** : Total ammount of vitamin_k present
#
# **calcium** : Total ammount of calcium present
#
# **copper** : Total ammount of copper present
#
# **irom** : Total ammount of irom present
#
# **magnesium** : Total ammount of magnesium present
#
# **manganese** : Total ammount of manganese present
#
# **phosphorous** : Total ammount of phosphorous present
#
# **potassium** : Total ammount of potassium present
#
# **selenium** : Total ammount of selenium present
#
# **zink** : Total ammount of zink present
#
# **protein** : Total ammount of protein present
#
# **alanine** : Total ammount of alanine present
#
# **arginine** : Total ammount of arginine present
#
# **aspartic_acid** : Total ammount of aspartic_acid present
#
# **cystine** : Total ammount of cystine present
#
# **glutamic_acid** : Total ammount of glutamic_acid present
#
# **glycine** : Total ammount of glycine present
#
# **histidine** : Total ammount of histidine present
#
# **hydroxyproline** : Total ammount of hydroxyproline present
#
# **isoleucine** : Total ammount of isoleucine present
#
# **leucine** : Total ammount of leucine present
#
# **lysine** : Total ammount of lysine present
#
# **methionine** : Total ammount of methionine present
#
# **phenylalanine** : Total ammount of phenylalanine present
#
# **proline** : Total ammount of proline present
#
# **serine** : Total ammount of serine present
#
# **threonine** : Total ammount of threonine present
#
# **tryptophan** : Total ammount of tryptophan present
#
# **tyrosine** : Total ammount of tyrosine present
#
# **valine** : Total ammount of valine present
#
# **carbohydrate** : Total ammount of carbohydrate present
#
# **fiber** : Total ammount of fiber present
#
# **sugars** : Total ammount of sugars present
#
# **fructose** : Total ammount of fructose present
#
# **galactose** : Total ammount of galactose present
#
# **glucose** : Total ammount of glucose present
#
# **lactose** : Total ammount of lactose present
#
# **maltose** : Total ammount of maltose present
#
# **sucrose** : Total ammount of sucrose present
#
# **fat** : Total ammount of fat present
#
# **saturated_fatty_acids** : Total ammount of saturated_fatty_acids present
#
# **monounsaturated_fatty_acids** : Total ammount of monounsaturated_fatty_acids present
#
# **polyunsaturated_fatty_acids** : Total ammount of polyunsaturated_fatty_acids present
#
# **fatty_acids_total_trans** : Total ammount of fatty_acids_total_trans present
#
# **alcohol** : Total ammount of alcohol present
#
# **ash** : Total ammount of ash present
#
# **caffeine** : Total ammount of caffeine present
#
# **theobromine** : Total ammount of theobromine present
#
# **water** : Total ammount of water present

# %% [markdown]
# ## Table of Content
#
# 1. **[Import Libraries](#lib)**
# 2. **[Data Preparation](#prep)**
#     - 2.1 - **[Understand the Data](#read)**
#     - 2.2 - **[Remove Insignificant Variables](#rmv)**
#     - 2.3 - **[Missing Value Analysis and Treatment](#null)**
#     - 2.4 - **[Duplicate Entries Analysis and Treatment](#dupl)**
#     - 2.5 - **[Data Cleaining](#cleaning)**
#     - 2.6 - **[Outlier Analysis and Treatment](#outlier)**
# 3.**[Descriptive Statistics](#ds)**
#     - 3.1 - **[Measures of Central tendencies](#ctd)**
#         - 3.1.1 - **[Mean](#mn)**
#         - 3.1.2 - **[Median](#mdn)**
#         - 3.1.3 - **[Mode](#md)**
#     - 3.2 - **[Measures of Dispersion](#dd)**
#         - 3.2.1 - **[Range](#rn)**
#         - 3.2.2 - **[standard Deviation](#sd)**
#         - 3.2.3 - **[Variance](#var)**
#         - 3.2.4 - **[Correlation](#cor)**
# 5. **[Visualization](#dv)**
#     - 5.1 - **[Histogram](#hist)**
#     - 5.2 - **[Count Plot](#count)**
#     - 5.3 - **[Skewness and Kurtosis](#sk)**
#     - 5.4 - **[Scatter Plot](#sp)**
#     - 5.5 - **[Density Plot](#dp)**
#     - 5.6 - **[Box Plot](#bp)**
#     - 5.7 - **[Boxen Plot](#bxp)**
#     - 5.8 - **[Bar Plot](#barp)**

# %% [markdown]
# <a id="lib"></a>
# # 1. Import Libraries
#
#
# Here we are importing the libraries that we will be using.

# %%
! pip install plotly

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import plotly.express as px
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_45076\3301129984.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# <a id="prep"></a>
# # 2. Data Preparation

# %% [markdown]
# <a id="read"></a>
# ## 2.1 Understand the Data
#
# **Loading the the dataset**
#
# You can load dataframe using `read_csv()` method from pandas.

# %%
df = pd.read_csv('nutrition_1.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             name serving_size  calories  \
# 0             0           0       Cornstarch        100 g       381
# 1             1           1     Nuts, pecans        100 g       691
# 2             2           2    Eggplant, raw        100 g        25
# 3             3           3   Teff, uncooked        100 g       367
# 4             4           4  Sherbet, orange        100 g       144
#
#    total_fat  saturated_fat  cholesterol  sodium  choline  ...      fat  \
# 0        0.1            NaN          0.0     9.0   0.4 mg  ...   0.05 g
# 1       72.0            6.2          0.0     0.0  40.5 mg  ...  71.97 g
# 2        0.2            NaN          0.0     2.0   6.9 mg  ...   0.18 g
# 3        2.4            0.4          0.0    12.0  13.1 mg  ...   2.38 g
# 4        2.0            1.2          1.0    46.0   7.7 mg  ...   2.00 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 0                  0.009                     0.016 g
# 1                  6.180                    40.801 g
# 2                  0.034                     0.016 g
# 3                  0.449                     0.589 g
# 4                  1.160                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol   ash caffeine  \
# 0                     0.025 g                 0.00 mg     0.0  0.09      0.0
# 1                    21.614 g                 0.00 mg     0.0  1.49      0.0
# 2                     0.076 g                 0.00 mg     0.0  0.66      0.0
# 3                     1.071 g                       0     0.0  2.37      0.0
# 4                     0.080 g                 1.00 mg     0.0  0.40      0.0
#
#   theobromine  water
# 0         0.0   8.32
# 1         0.0   3.52
# 2         0.0  92.30
# 3         0.0   8.82
# 4         0.0  66.10
#
# [5 rows x 78 columns]

# %% [markdown]
# Here we are loding the `csv` files as pandas dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0.1                 8789 non-null   int64
#  1   Unnamed: 0                   8789 non-null   int64
#  2   name                         8789 non-null   object
#  3   serving_size                 8789 non-null   object
#  4   calories                     8789 non-null   int64
#  5   total_fat                    8789 non-null   float64
#  6   saturated_fat                7199 non-null   float64
#  7   cholesterol                  8789 non-null   float64
#  8   sodium                       8789 non-null   float64
#  9   choline                      8789 non-null   object
#  10  folate                       8789 non-null   object
#  11  folic_acid                   8789 non-null   float64
#  12  niacin                       8789 non-null   object
#  13  pantothenic_acid             8789 non-null   object
#  14  riboflavin                   8789 non-null   object
#  15  thiamin                      8789 non-null   object
#  16  vitamin_a                    8789 non-null   float64
#  17  vitamin_a_rae                8789 non-null   object
#  18  carotene_alpha               8789 non-null   object
#  19  carotene_beta                8789 non-null   object
#  20  cryptoxanthin_beta           8789 non-null   object
#  21  lutein_zeaxanthin            8789 non-null   object
#  22  lucopene                     8789 non-null   int64
#  23  vitamin_b12                  8789 non-null   float64
#  24  vitamin_b6                   8789 non-null   float64
#  25  vitamin_c                    8789 non-null   float64
#  26  vitamin_d                    8789 non-null   float64
#  27  vitamin_e                    8789 non-null   float64
#  28  tocopherol_alpha             8789 non-null   object
#  29  vitamin_k                    8789 non-null   object
#  30  calcium                      8789 non-null   float64
#  31  copper                       8789 non-null   object
#  32  irom                         8789 non-null   float64
#  33  magnesium                    8789 non-null   object
#  34  manganese                    8789 non-null   object
#  35  phosphorous                  8789 non-null   object
#  36  potassium                    8789 non-null   object
#  37  selenium                     8789 non-null   object
#  38  zink                         8789 non-null   object
#  39  protein                      8789 non-null   float64
#  40  alanine                      8789 non-null   object
#  41  arginine                     8789 non-null   object
#  42  aspartic_acid                8789 non-null   object
#  43  cystine                      8789 non-null   object
#  44  glutamic_acid                8789 non-null   object
#  45  glycine                      8789 non-null   object
#  46  histidine                    8789 non-null   object
#  47  hydroxyproline               8789 non-null   object
#  48  isoleucine                   8789 non-null   object
#  49  leucine                      8789 non-null   object
#  50  lysine                       8789 non-null   object
#  51  methionine                   8789 non-null   object
#  52  phenylalanine                8789 non-null   object
#  53  proline                      8789 non-null   object
#  54  serine                       8789 non-null   object
#  55  threonine                    8789 non-null   object
#  56  tryptophan                   8789 non-null   object
#  57  tyrosine                     8789 non-null   object
#  58  valine                       8789 non-null   object
#  59  carbohydrate                 8789 non-null   float64
#  60  fiber                        8789 non-null   float64
#  61  sugars                       8789 non-null   float64
#  62  fructose                     8789 non-null   float64
#  63  galactose                    8789 non-null   float64
#  64  glucose                      8789 non-null   float64
#  65  lactose                      8789 non-null   float64
#  66  maltose                      8789 non-null   float64
#  67  sucrose                      8789 non-null   float64
#  68  fat                          8789 non-null   object
#  69  saturated_fatty_acids        8789 non-null   float64
#  70  monounsaturated_fatty_acids  8789 non-null   object
#  71  polyunsaturated_fatty_acids  8789 non-null   object
#  72  fatty_acids_total_trans      8789 non-null   object
#  73  alcohol                      8789 non-null   float64
#  74  ash                          8789 non-null   float64
#  75  caffeine                     8789 non-null   float64
#  76  theobromine                  8789 non-null   float64
#  77  water                        8789 non-null   float64
# dtypes: float64(29), int64(4), object(45)
# memory usage: 5.2+ MB

# %% [markdown]
# **Size of datframe**
#
# You can find size of dataframe using the `shape` attribute of the dataframe.

# %%
df.shape

# %% [markdown]
#  ## How to find the or differenciate the categorical data and numerical data

# %%
num=df._get_numeric_data()
num.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  calories  total_fat  saturated_fat  cholesterol  \
# 0             0           0       381        0.1            NaN          0.0
# 1             1           1       691       72.0            6.2          0.0
# 2             2           2        25        0.2            NaN          0.0
# 3             3           3       367        2.4            0.4          0.0
# 4             4           4       144        2.0            1.2          1.0
#
#    sodium  folic_acid  vitamin_a  lucopene  ...  glucose  lactose  maltose  \
# 0     9.0         0.0        0.0         0  ...     0.00      0.0     0.00
# 1     0.0         0.0       56.0         0  ...     0.04      0.0     0.00
# 2     2.0         0.0       23.0         0  ...     1.58      0.0     0.00
# 3    12.0         0.0        9.0         0  ...     0.73      0.0     0.01
# 4    46.0         0.0       46.0         0  ...     0.00      0.0     0.00
#
#    sucrose  saturated_fatty_acids  alcohol   ash  caffeine  theobromine  water
# 0     0.00                  0.009      0.0  0.09       0.0          0.0   8.32
# 1     3.90                  6.180      0.0  1.49       0.0          0.0   3.52
# 2     0.26                  0.034      0.0  0.66       0.0          0.0  92.30
# 3     0.62                  0.449      0.0  2.37       0.0          0.0   8.82
# 4     0.00                  1.160      0.0  0.40       0.0          0.0  66.10
#
# [5 rows x 33 columns]

# %%
cat=df.drop(num,axis=1)
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   object
#  2   choline                      8789 non-null   object
#  3   folate                       8789 non-null   object
#  4   niacin                       8789 non-null   object
#  5   pantothenic_acid             8789 non-null   object
#  6   riboflavin                   8789 non-null   object
#  7   thiamin                      8789 non-null   object
#  8   vitamin_a_rae                8789 non-null   object
#  9   carotene_alpha               8789 non-null   object
#  10  carotene_beta                8789 non-null   object
#  11  cryptoxanthin_beta           8789 non-null   object
#  12  lutein_zeaxanthin            8789 non-null   object
#  13  tocopherol_alpha             8789 non-null   object
#  14  vitamin_k                    8789 non-null   object
#  15  copper                       8789 non-null   object
#  16  magnesium                    8789 non-null   object
#  17  manganese                    8789 non-null   object
#  18  phosphorous                  8789 non-null   object
#  19  potassium                    8789 non-null   object
#  20  selenium                     8789 non-null   object
#  21  zink                         8789 non-null   object
#  22  alanine                      8789 non-null   object
#  23  arginine                     8789 non-null   object
#  24  aspartic_acid                8789 non-null   object
#  25  cystine                      8789 non-null   object
#  26  glutamic_acid                8789 non-null   object
#  27  glycine                      8789 non-null   object
#  28  histidine                    8789 non-null   object
#  29  hydroxyproline               8789 non-null   object
#  30  isoleucine                   8789 non-null   object
#  31  leucine                      8789 non-null   object
#  32  lysine                       8789 non-null   object
#  33  methionine                   8789 non-null   object
#  34  phenylalanine                8789 non-null   object
#  35  proline                      8789 non-null   object
#  36  serine                       8789 non-null   object
#  37  threonine                    8789 non-null   object
#  38  tryptophan                   8789 non-null   object
#  39  tyrosine                     8789 non-null   object
#  40  valine                       8789 non-null   object
#  41  fat                          8789 non-null   object
#  42  monounsaturated_fatty_acids  8789 non-null   object
#  43  polyunsaturated_fatty_acids  8789 non-null   object
#  44  fatty_acids_total_trans      8789 non-null   object
# dtypes: object(45)
# memory usage: 3.0+ MB

# %%
# Out:
# (8789, 78)

# %% [markdown]
# We can determine the number of rows and columns observing the shape of the dataframe

# %%
# name of the columns
a = list(df.columns)
for i in a:
  print(i)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# name
# serving_size
# calories
# total_fat
# saturated_fat
# cholesterol
# sodium
# choline
# folate
# folic_acid
# niacin
# pantothenic_acid
# riboflavin
# thiamin
# vitamin_a
# vitamin_a_rae
# carotene_alpha
# carotene_beta
# cryptoxanthin_beta
# lutein_zeaxanthin
# lucopene
# vitamin_b12
# vitamin_b6
# vitamin_c
# vitamin_d
# vitamin_e
# tocopherol_alpha
# vitamin_k
# calcium
# copper
# irom
# magnesium
# manganese
# phosphorous
# potassium
# selenium
# zink
# protein
# alanine
# arginine
# aspartic_acid
# cystine
# glutamic_acid
# glycine
# histidine
# hydroxyproline
# isoleucine
# leucine
# lysine
# methionine
# phenylalanine
# proline
# serine
# threonine
# tryptophan
# tyrosine
# valine
# carbohydrate
# fiber
# sugars
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat
# saturated_fatty_acids
# monounsaturated_fatty_acids
# polyunsaturated_fatty_acids
# fatty_acids_total_trans
# alcohol
# ash
# caffeine
# theobromine
# water

# %% [markdown]
# <a id="rmv"></a>
# ## 2.2 Remove Insignificant Variables
#
# We'll be focusing on the numerical data and remove feature that contain any other form of data. Here we're removing the columns named "Unamed: 0", "Unnamed: 0.1", "lucopene" and "Serving_Size"which are not needed to get insights from the data
# <br>
#
# Serving size is not necessary since for all records the serving size is same which is `100 g`
# <br>
#
# lucopene is not necessary since for all records the serving size is same which is `0`

# %% [markdown]
# you can drop columns usning `drop()` method.
# You can read more about it on <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html">This Link </a>

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1','serving_size', 'lucopene'],axis=1,inplace=True)

# %% [markdown]
# By dropping uncessary columns we can make statistical analyis easy and efficent.<br>
# The size of the dataset decreases and so performance of the methods becomes faster.

# %% [markdown]
# <a id="null"></a>
# ## 2.3 Missing Value Analysis and Treatment

# %% [markdown]
# You can check whether the value is null value or not by using the method called as `isna()`.While the `sum()` method gives total number of null entries.
#
# You can read more about `isna()` on <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html"> This link</a>.

# %%
null_per = pd.DataFrame({'count':df.isna().sum(),'Percentage':df.isna().sum()*100/8789})
null_per
# Out:
#                count  Percentage
# name               0    0.000000
# calories           0    0.000000
# total_fat          0    0.000000
# saturated_fat   1590   18.090795
# cholesterol        0    0.000000
# ...              ...         ...
# alcohol            0    0.000000
# ash                0    0.000000
# caffeine           0    0.000000
# theobromine        0    0.000000
# water              0    0.000000
#
# [74 rows x 2 columns]

# %%
null_per.Percentage.value_counts()
# Out:
# Percentage
# 0.000000     73
# 18.090795     1
# Name: count, dtype: int64

# %% [markdown]
# The feature saturated_fat has around 18% of null entries. As a significant chunk of the dataset is empty, we can impute the null values in the feature, saturated_fat.<br>
# If dataset has outliers, mean imputation is not a good option. In such case, imputation with median is suggested.

# %%
# Check whether saturated_fat has outliers
sns.boxplot(df['saturated_fat'])
plt.show()

# %% [markdown]
# From above plot, we come to know that saturated_fat feature has many outliers, so impute the null values in the saturated_fat feature by median value of available values.

# %%
df['saturated_fat'] = df['saturated_fat'].fillna(df['saturated_fat'].median())

# %%
df.isna().sum()
# Out:
# name             0
# calories         0
# total_fat        0
# saturated_fat    0
# cholesterol      0
#                 ..
# alcohol          0
# ash              0
# caffeine         0
# theobromine      0
# water            0
# Length: 74, dtype: int64

# %% [markdown]
# The dataset is now completely free from the missing values.

# %% [markdown]
# <a id="dupl"></a>
# ## 2.4 Duplicate Entries Analysis and Treatment

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate entries in the dataset.

# %% [markdown]
# <a id="cleaning"></a>
# ## 2.5 Data Cleaning
#
# Many times we can face situations, where the data may not be in proper format. The data could contain use less noise which can throw our ML algorithms off when making predictions. We need to clean our data to overcome that

# %%
df['diiff']=[i for i in range(len(df['name']))]

# %%
df
# Out:
#                                                    name  calories  total_fat  \
# 0                                            Cornstarch       381        0.1
# 1                                          Nuts, pecans       691       72.0
# 2                                         Eggplant, raw        25        0.2
# 3                                        Teff, uncooked       367        2.4
# 4                                       Sherbet, orange       144        2.0
# ...                                                 ...       ...        ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...       125        3.5
# 8785  Lamb, cooked, separable lean only, composite o...       206        8.9
# 8786  Lamb, raw, separable lean and fat, composite o...       277       23.0
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...       121        3.0
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...       121        3.0
#
#       saturated_fat  cholesterol  sodium  choline     folate  folic_acid  \
# 0               2.2          0.0     9.0   0.4 mg   0.00 mcg         0.0
# 1               6.2          0.0     0.0  40.5 mg  22.00 mcg         0.0
# 2               2.2          0.0     2.0   6.9 mg  22.00 mcg         0.0
# 3               0.4          0.0    12.0  13.1 mg          0         0.0
# 4               1.2          1.0    46.0   7.7 mg   4.00 mcg         0.0
# ...             ...          ...     ...      ...        ...         ...
# 8784            1.4         62.0    54.0  64.5 mg   4.00 mcg         0.0
# 8785            3.9        109.0    50.0        0   0.00 mcg         0.0
# 8786           12.0         78.0    39.0        0   1.00 mcg         0.0
# 8787            1.1         60.0    53.0  64.2 mg   4.00 mcg         0.0
# 8788            1.1         60.0    53.0  64.2 mg   4.00 mcg         0.0
#
#         niacin  ... saturated_fatty_acids monounsaturated_fatty_acids  \
# 0     0.000 mg  ...                 0.009                     0.016 g
# 1     1.167 mg  ...                 6.180                    40.801 g
# 2     0.649 mg  ...                 0.034                     0.016 g
# 3     3.363 mg  ...                 0.449                     0.589 g
# 4     0.063 mg  ...                 1.160                     0.530 g
# ...        ...  ...                   ...                         ...
# 8784  6.422 mg  ...                 1.353                     1.554 g
# 8785  7.680 mg  ...                 3.860                     3.480 g
# 8786  6.550 mg  ...                11.570                     8.720 g
# 8787  6.720 mg  ...                 1.086                     1.266 g
# 8788  6.720 mg  ...                 1.086                     1.266 g
#
#      polyunsaturated_fatty_acids  fatty_acids_total_trans alcohol   ash  \
# 0                        0.025 g                  0.00 mg     0.0  0.09
# 1                       21.614 g                  0.00 mg     0.0  1.49
# 2                        0.076 g                  0.00 mg     0.0  0.66
# 3                        1.071 g                        0     0.0  2.37
# 4                        0.080 g                  1.00 mg     0.0  0.40
# ...                          ...                      ...     ...   ...
# 8784                     0.244 g                 62.00 mg     0.0  1.11
# 8785                     0.520 g                109.00 mg     0.0  1.60
# 8786                     0.980 g                 78.00 mg     0.0  0.92
# 8787                     0.233 g                 60.00 mg     0.0  1.10
# 8788                     0.233 g                 60.00 mg     0.0  1.10
#
#      caffeine theobromine  water  diiff
# 0         0.0         0.0   8.32      0
# 1         0.0         0.0   3.52      1
# 2         0.0         0.0  92.30      2
# 3         0.0         0.0   8.82      3
# 4         0.0         0.0  66.10      4
# ...       ...         ...    ...    ...
# 8784      0.0         0.0  72.51   8784
# 8785      0.0         0.0  59.95   8785
# 8786      0.0         0.0  59.80   8786
# 8787      0.0         0.0  73.43   8787
# 8788      0.0         0.0  73.43   8788
#
# [8789 rows x 75 columns]

# %%
df.columns
# Out:
# Index(['name', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'vitamin_b12', 'vitamin_b6',
#        'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha', 'vitamin_k',
#        'calcium', 'copper', 'irom', 'magnesium', 'manganese', 'phosphorous',
#        'potassium', 'selenium', 'zink', 'protein', 'alanine', 'arginine',
#        'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine', 'histidine',
#        'hydroxyproline', 'isoleucine', 'leucine', 'lysine', 'methionine',
#        'phenylalanine', 'proline', 'serine', 'threonine', 'tryptophan',
#        'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars', 'fructose',
#        'galactose', 'glucose', 'lactose', 'maltose', 'sucrose', 'fat',
#        'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %% [markdown]
# We can see that all columns other than name are numeric columns. However not all are formatted properly. Hence we must make these columns numerical and fit for analysis.

# %%
# get list of all column names
all_cols = df.columns
# get a list of numeric column names
num_cols = df.select_dtypes(['int32', 'int64', 'float32', 'float64'])
# get a list of unformated/unclean columns
unformated_cols = [x for x in all_cols if x not in num_cols]
# removing categorical columns
unformated_cols.remove('name')

print(unformated_cols)
print(len(unformated_cols))

# %%
for i in unformated_cols:
    # save new name of column to `new_col1 var
    new_col = f"{i} ({df[i][0].split(' ')[-1]})"
    # change column name
    df = df.rename(columns = {i: new_col})
    # format data
    df[new_col] = df[new_col].apply(lambda row: row.split(' ')[0])
    # change data type of the columns
    df[new_col] = df[new_col].astype(float)

num_cols = df.select_dtypes(['int32', 'int64', 'float32', 'float64']).columns
df.select_dtypes(['int32', 'int64', 'float32', 'float64'])

# %% [markdown]
# <a id="outlier"></a>
# ## 2.6 Outlier Analysis and Treatment
#
# There are many ways to detect the outliers.<br>
# Mostly used and hihgly efficient ways to detect the outliers are using z score and IQR.
# 1. Outlier detection using `z score` method: The data points for which the z score is greater than `3` are treated as outliers.
# 2. Outlier detection using `IQR`: The datapoints which are falling outside the range of q1 - 1.5iqr and q3 +1.5iqr.<br>
# where `iqr = q3 - q1`.

# %% [markdown]
# 1. Detect outliers using the z score for sugars variable

# %% [markdown]
# * The very first step will be setting the upper and lower limit. This range stimulates that every data point will be regarded as an outlier out of this range. Let’s see the formulae for both upper and lower limits.
# * Upper: Mean + 3 * standard deviation.
# * Lower: Mean – 3 * standard deviation.

# %% [markdown]
# * Here we are detecting how many outliers are there in the dataset based on the upper and lower limit that we set up just

# %%
def upper(x):
   return (x.mean() + 3*x.std())

# %%
import numpy as np

def upper(x):
    x_np = np.array(x)
    return (x_np.mean() + 3 * x_np.std())

# %%
upper(df)

# %%
# iterate through df columns
for i in num_cols:
    Upper_limit=df[i].mean() + 3*df[i].std()
    Lower_lmit=df[i].mean() -3*df[i].std()
    # print column name
    print(i)
    # print upper limit of the column
    print(f"Upper limit",upper(i)) # column.mean() + 3column.std()
    # print lower limit of the column
    print(f"lower limit",Lower_lmit)
    # get shape of outlier dataframe 
    temp = df[(df[i] > Upper_limit) | (df[i] < Lower_lmit)].shape
    # print the Standard Deviation of the column
    print(f"Standard Deviation: {df[i].std()}")
    print(f"shape of outlier dataframe: {temp}")
    # get percentage of outlier data
    percentage = temp[0]/df.shape[0] * 100
    print(f"Percentage of Outliers: {percentage}")

# %% [markdown]
# The above output is the index for outlier datapoints.
#
# 2. Detect outliers using the IQR method for sugars variable

# %%
df

# %%
for i in num_cols:
    print(i)
    q1 = np.percentile(df[i], 25, interpolation='midpoint')
    q3 = np.percentile(df[i], 75, interpolation='midpoint')
    iqr = q3 - q1
    ul = q3 +1.5*iqr
    ll = q1 - 1.5*iqr
    outliers = df[(df[i] > ul) | (df[i] < ll)]
    print(f"Shape of outliers: {outliers.shape}")
    print(f"Percentage of outliers: {outliers.shape[0]/df.shape[0] * 100}")

# %% [markdown]
# * We can see there's quite a big number of outliers in our dataset.
# * To remove these outliers we can use the code below

# %%
# iterate through df columns
for i in num_cols:
    # print column name
    print(i)
    # print upper limit of the column
    print(f"Upper limit",df[i].mean() + 3*df[i].std())
    # print lower limit of the column
    print(f"lower limit",df[i].mean() - 3*df[i].std())
    # get shape of outlier dataframe 
    df = df[~(df[i] > df[i].mean() + 3*df[i].std()) | (df[i] < df[i].mean() - 3*df[i].std())]

df

# %% [markdown]
# <a id="prep"></a>
# # 3. Descriptive Statistics
# Within descriptive statistics, there are two measures used to describe the data:
# 1. Central tendency: It refers to the central position of the data (mean, median, mode)
# 2. Deviation: It describes how far spread out the data are from the mean. The deviation is most commonly measured with the standard deviation.

# %% [markdown]
# <a id="cte"></a>
# ## 3.1. Measures of Central tendencies
#
#
# Let's First start with the Central tendency.<br>
# It mainly contains three operations :
# 1. Mean.
# 2. Median.
# 3. Mode.

# %% [markdown]
# <a id="mn"></a>
# ### 3.1.1 Mean
# The “Mean” is the average of the data.<br>
# Average can be identified by summing up all the numbers and then dividing them by the number of observations.
#
# Mean = X1 + X2 + X3 +… +  Xn / n

# %% [markdown]
# Find the mean of for all the columns.<br>
#
# Hint:- You can find the mean of columns using `mean` method from pandas dataframe.

# %%
df.mean()

# %% [markdown]
# <a id="mdn"></a>
# ### 3.1.2 Median
# The Median is the 50th percentile of the data. It is precisely the center point of the data.
#
# The Median can be identified by ordering the data and splitting the data into two equal parts and finding the number. It is the best way to find the center of the data.

# %% [markdown]
# Find the median for all the columns
#
# <b>Hint:-</b> There is median method is available in pandas dataframe. You can use it.

# %%
df.median()

# %% [markdown]
# <a id="md"></a>
# ### 3.1.3 Mode
# * Mode is frequently occurring data or elements.
#
# * If an element occurs the highest number of times, it is the mode of that data. If no number in the information is repeated, then there is no mode for that data. There can be more than one mode in a dataset if two values have the same and highest frequency.
#
# * Outliers don’t influence the data.
#
# * The mode can be calculated for both quantitative and qualitative data.

# %% [markdown]
# ### Find the Mode for categorical variables.
#
# Hint :- You can use the `mode()` method to find mode of the given columns

# %%
df['name'].value_counts()

# %%
df['name'].duplicated().sum()

# %%
df['name'].nunique()

# %%
df['name'].mode()

# %% [markdown]
# Categorical feature, name do not has any repetation all the entries are unique.<br> So it do not has mode.

# %% [markdown]
# ### Find the Mode for numerical variables.

# %%
num_features = df.select_dtypes(['int32', 'int64', 'float32', 'float64']).columns
num_features

# %%
df_mode = []
# int_features = list(df.select_dtypes(include=['int64']).columns)
# float_features = list(df.select_dtypes(include=['float64']).columns)
# num_features = int_features + float_features

num_features = df.select_dtypes(['int32', 'int64', 'float32', 'float64']).columns
for i in num_features:
  df_mode.append(df[i].mode().values)

pd.DataFrame({'Name':num_features, "Mode":df_mode})
num_features

# %% [markdown]
# * The above table shows the mode for all the columns in the dataset.

# %% [markdown]
# ### limitations of Central tendencies
#
# 1. mean is highly influenced by extreme values/outliers.
# 2. Mean is not a good representative of data for skewed distribution.
# 2. Measures of Central tendency gives only one representative value for each variables.

# %% [markdown]
# <a id="dd"></a>
# ## 3.2 Measures of Dispersion
# 1. It describes the spread of the data.
# 2. Variance and Standard deviation gives the idea about distance of each point from mean the.
# 3. Standard deviation is the square root of variance.

# %% [markdown]
# <a id="rn"></a>
# ### 3.2.1 Range

# %% [markdown]
# Range is the difference between maximum and minimum value.<br>
# Find minimum and maximum values for variable, alcohol.<br>
# Hint :- You can find the maximum and minimum values using `max()` and `min()` method from pandas.

# %%
df

# %%
df=df.iloc[:,1:]
df

# %%
df_max = []
df_min = []
df_range = []
for i in num_features:
  df_max.append(df[[i]].max())
  df_min.append(df[[i]].min())
  df_range.append(df[[i]].max() - df[[i]].min())

# %%
df_range

# %% [markdown]
# Vitamin_a has the highest range which is 100000 while hydroxyproline has the least range 1.13.

# %% [markdown]
# You can get idea about range of values by finding the maximum and minimium values.

# %% [markdown]
# Find the Numbers of Unique values in the column named "alcohol".<br>
# You can find the number of unique values in the column using, `nunique()` method from pandas.

# %%
df.nunique()

# %% [markdown]
# <a id="var"></a>
# ### 3.2.2 Variance
# The variance is a measure of variability.<br> It is the average squared deviation from the mean.<br>
# Varinace tells about how each point is far away from mean value.

# %% [markdown]
# Find the variance of the column named "total_fat".<br>
# Hint :- You can use the `var()` method to find the variance of the given column.

# %%
df.var()

# %% [markdown]
# <a id="sd"></a>
# ### 3.2.3 Standard Derivation
# Standard deviation is the square root of variance.<br>
# The Standard deviation is the measure of how far the data deviates from the mean value.<br>
# It is most common measure of spread of data.
# <br>
#
# Hint :- You can find the Standard derivation using the `std` method.

# %%
df.std()

# %% [markdown]
# #### Finding the central tendency and dispersion of data for the column "alcohol" using `describe()` method.
# <ul>
# <li> total numbers of rows in column</li>
# <li> mean </li>
# <li> standard derivation </li>
# <li> Minimum values </li>
# <li> Maximum values </li>
# <li> 25%,50%,75% percentile values </li>

# %% [markdown]
# You can use `describe()` method to find all the above things.
# <br>
#
# You can read more about it from <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html"> This link </a>

# %%
df.describe()

# %% [markdown]
# <a id="cor"></a>
# ### 3.2.4 Correlation

# %% [markdown]
# Find the correlation between all the columns.<br>
#
# Hint:- You can use `corr()` method to find the correlationship between all the columns

# %%
df.corr()

# %% [markdown]
# There is highest positive correlation between saturated_fatty_acid and saturated_fat.<br>
# There is highest negative correlation between calories and water.

# %% [markdown]
# **Heat Map**
#
# Heat Maps are graphical representations of data that utilize color-coded systems. The primary purpose of Heat Maps is to better visualize the volume of locations/events within a dataset and assist in directing viewers towards areas on data visualizations that matter most.
#
# Plot the heatmap for all the features in the given dataset.
#
# Hint : You can use `heatmap()` method from seaborn package to create heatmap.

# %%
corr = df2.corr()
_, ax = plt.subplots(figsize=(13,10)) 

# graph correlation matrix
_ = sns.heatmap(corr, ax=ax,
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
                cmap='coolwarm')

# %% [markdown]
# The result of the correlation tells how each column is related to the other.
#
# The number varies from -1 to 1 where 1 means that there is a 1-to-1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good a relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# What is a good correlation? It depends on the use, but I think it is safe to say you have to have at least

# %% [markdown]
# <a id="viz"></a>
# # 5. Visualization

# %% [markdown]
# <a id="hist"></a>
# # 5.1 Histogram
#
# histogram is a bar graph-like representation of data that buckets a range of classes into columns along the horizontal x-axis. The vertical y-axis represents the number count or percentage of occurrences in the data for each column. Columns can be used to visualize patterns of data distributions.

# %% [markdown]
# Find the distribution of the following all the numerical columns using histogram
#
# Hint :- You can plot the histogram using the `hist()` method of the pandas dataframe.

# %%
plt.figure(figsize=(15,15))

hist_df = df[num_features]
hist_df.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# From above histogram, we can see that all the features are right skewed except for feature called water.

# %%
px.histogram(x=df['total_fat'])

# %%
px.histogram(x=df['protein'])

# %%
px.histogram(x=df['calories'])

# %%
px.histogram(x=df['cholesterol'])

# %% [markdown]
# The variables sugars, total_fat and protein are right skewed.
#
# **As the dataset is quite large, we have shown a few examples here. However, we encourage the learners to try with as many variables the can**

# %% [markdown]
# <a id="viz"></a>
# # 5.2 Count Plot
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.<br>
# You can read more about `countplot()` on <a href="https://seaborn.pydata.org/generated/seaborn.countplot.html#:~:text=Show%20the%20counts%20of%20observations,compare%20counts%20across%20nested%20variables."> This link </a>.

# %% [markdown]
# Plot a count plot for the first 50 rows of macro nutrients, protein, carbohydrate, total_fat.<br>
#
# Hint: -You can use the seaborn pakage from plotting the count plot and don't forget to slice the dataframe.

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df[:50], x="protein")
plt.title('Countplot for protein')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df[:50], x="carbohydrate")
plt.title('Countplot for Carbohydrate')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df[:50], x="total_fat")
plt.title('Countplot for total_fat')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Protein content present in most of the food items in first 50 rows is 0.0.
# * The carbohyderate level present in food items in first 50 rows is most of the time 0.0 or 6.25 or 42.6
# * Most of the food items in first 50 rows has total_fat level upto 0.5 or 16.0.

# %% [markdown]
# Plot a count plot for the last 50 rows of macro nutrients, protein, carbohydrate, total_fat.

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df.tail(50), x="protein")
plt.title('Countplot for protein')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df.tail(50), x="carbohydrate")
plt.title('Countplot for Carbohydrate')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data=df.tail(50), x="total_fat")
plt.title('Countplot for total_fat')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Protein content present in most of the food items in last 50 rows is 23.37 or 29.59.
# * The carbohyderate level present in food items in last 50 rows is most of the time 0.0.
# * Most of the food items in last 50 rows has total_fat level upto 20.
#
# **As the dataset is quite large, we have shown a few examples here. However, we encourage the learners to try with as many variables the can**

# %% [markdown]
# <a id="sk"></a>
# # 5.3 Skewness and Kurtosis
#
# Skewness is the measure of the asymmetry of the distribution of data.<br>
# The data is not symmetrical (i.e) it is skewed towards one side.<br>
# While Kurtosis is the measure of describing the distribution of data.

# %% [markdown]
# Find the Skewness and Kurtosis for all the columns.<br>
#
# You can find the Skewness and Kurtosis using `kurt()` and `skew()` method which are available in pandas dataframe

# %%
df.kurt()

# %%
# list(df.kurt().values)
pd.set_option('display.max_rows', 74)
pd.DataFrame(df.kurt())

# %% [markdown]
# * A distribution with kurtosis < 3 follows platykurtic distribution and with kurtosis > 3 follows leptokurtic distribution.<br>
# * In comparison to a normal distribution, a platykurtic distribution will have thinner tails while leptokurtic distribution will have flatter tails.<br>
# * A statistical distribution with negative excess kurtosis is also referred to as "platykurtic."<br>
# * The extreme occurrences are less frequent than in a normal distribution for platykurtic distribution and most frequent than in a normal distribution for leptokurtic distribution .
# * The features calories, protein, glutamic_acid, histidine isoleucine, leucine, lysine, threonine, tyrosine, carbohydrate, water has the platykurtic distribution while rest of the features are said to be leptokurtic.<br>

# %%
df.skew()

# %% [markdown]
# * When a data set is symmetrical, its mean, median, and mode are all equal. A data set is said to be skewed in that direction if one side of the middle has more extreme individuals than the other.
# * None of the feature has symmetrical distribution since the skewness is not 0 for any of the fature.<br>
# * The left side of the peak of a negatively skewed distribution is longer than the right.
# * The feature, water is negatively skewed since its skewness value is negative.
# * galactose and caffeine are highly right skewed features.

# %% [markdown]
# <a id="sp"></a>
# # 5.4 Scatter plot
#
# The Scatter plot is used to find the relationship between two parameters in other words, we can say the scatter plot is used to show us how two variables are related to each other.

# %% [markdown]
# Plot a scatter plot for columns "water" v/s "sugars" to find relationship between them.<br>
#
# Hint :- You can use the `scatterplot()` method from the seaborn pakage for drawing scatterplot.
# <br>
#
# You can read more about it on <a href="https://seaborn.pydata.org/generated/seaborn.scatterplot.html">This link </a>

# %%
sns.scatterplot(data=df, x="water", y="sugars")

# %% [markdown]
# The food items which have highest water level have less sugar level for most of the times.

# %% [markdown]
# The above method is for ploting scatter plot for a limited variables/columns.
#
# Here we can see how plot a scatter plot for all columns in the dataset.
# We can use `pairplot()` method provided by seaborn to get scatter plots of all the columns in a dataset.

# %%
sns.pairplot(df)

# %% [markdown]
# <a id="dp"></a>
# # 5.5 Density Plot
#
# Like a smoother histogram, a density plot shows data. <br>
# In density plots, the kernel density estimate is typically used to display the probability density function of the variable. <br>
# To get a smooth density estimate for the whole set of data, a continuous curve—the kernel—is created.<br>
# Density plot helps to get the distribution of variable in a feature.

# %% [markdown]
# Plot the density plot for column, sugars.
#
# Hint :- You can use the `density()` method from the seaborn pakage for drawing scatterplot. We can do the same plot using seaborn with this code :
#  `sns.kdeplot(data=df, x="sugars")`
# <br>
#
# You can read more about it on <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.density.html">This link </a>

# %%
df['sugars'].plot.density()
plt.title('Density Plot for sugars')
plt.show()

# %% [markdown]
# Variable sugars is right skewed.
#
# **As the dataset is quite large, we have shown a few examples here. However we encourage the learners to try with as many variables the can**

# %% [markdown]
# <a id="bp"></a>
# # 5.6 Box Plot
#
# The box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between  the variables or across levels of a categorical variable.<br> The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the interquartile range.

# %% [markdown]
# Draw a boxplot for the columns "water" and "sugars".<br>
#
# Hint :- You can use `boxplot` method of pandas dataframe to create boxplot for it.

# %% [markdown]
# Plotting boxplot on single feature

# %%
df[['water','sugars']].boxplot()

# %% [markdown]
# The variable water has no outliers.<br>
# The variable sugars has many outliers.

# %% [markdown]
# The above method is for ploting box plot for a limited variables/columns.
#
# Here we can see how plot a box plot for all columns in the dataset.
# We can use `boxplot()` method provided by pandas to get box plots of all the columns in a dataset.

# %%
plt.figure(figsize=(60,15))

hist_df = df[num_features]
              
hist_df.boxplot(figsize=(50,50))
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# <a id="bxp"></a>
# # 5.7 Boxen Plot
# The boxen plot is an enhanced version of boxplot. It provides more information about the shape of the distribution and also helps to get the outliers present in the dataset more clearly than that of boxplots.

# %% [markdown]
# Plot three diffrent boxenplot for following columns using `seaborn` pakage.<br>
# <ul>
# <li>sugars</li>
# <li>water</li>

# %% [markdown]
# Hint :- You can use the `boxenplot()` method from seaborn pakage to create the boxenplot.

# %% [markdown]
# To plot individual boxenplot we'll pass one column value.

# %%
sns.boxenplot(x=df['sugars'])

# %%
sns.boxenplot(x=df['water'])

# %% [markdown]
# The above method is for ploting boxen plot for a limited variables/columns.
#
# Here we can see how plot a boxen plot for all columns in the dataset.
# We can use `boxenplot()` method provided by seaborn to get boxen plots of all the columns in a dataset.

# %% [markdown]
# Plotting the boxen plot for all features

# %%
fig, ax = plt.subplots(figsize=(70,20))
p = sns.boxenplot(data=hist_df)
p.set(ylabel='My yLabel', xlabel='My xLabel')
plt.show()

# %% [markdown]
# <a id="barp"></a>
# # 5.8 Bar Plot
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars.<br>
# You can read more about it on <a href="https://seaborn.pydata.org/generated/seaborn.barplot.html">This link </a>

# %% [markdown]
# Plot the barplot for variance of  features like, vitamin_b12, vitamin_e, fiber, fructose, glucose, lactose, sucrose, alcohol, ash.<br>
#
# Hint : You can use `barplot()` method from seaborn package to create barplot.

# %%
# Get the vaariance for selected features
# variance = df[['vitamin_b12', 'vitamin_e', 'fiber', 'fructose', 'glucose', 'lactose', 'sucrose', 'alcohol', 'ash']].var()
variance = df[num_cols].var()
var_df = df[num_cols]

# Get column with max variance
print(variance.idxmax())

# Get column with min variance
print(variance.idxmin())

# Plot the bar plot
plt.figure(figsize=(15,8))
ax = sns.barplot(x=variance.index.tolist(), y=variance.values.tolist())
# Rotate X axis coordinates vertically.
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# The variance for variable, vitamin_a is very high while galactose has very less variance.
